# %% [markdown]
# Q20 ヒストグラムの表示

# %%
import numpy as np
import matplotlib.pyplot as plt 
import cv2

imori_dark = cv2.imread("imori_dark.jpg")

# %%
def histgram(h_img):
    plt.hist(h_img.ravel(), bins=255, range=(0, 255), rwidth=0.7 )
plt.show()

# %%
plt.hist(imori_dark.ravel(), bins=255, range=(0, 255), rwidth=0.7 )
plt.show()
